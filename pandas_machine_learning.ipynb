# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %% [markdown]
# Pandas Series

# %%
my_series = [2,4,5,3,6,7,8]
my_var = pd.Series(my_series)
my_var
# Out:
# 0    2
# 1    4
# 2    5
# 3    3
# 4    6
# 5    7
# 6    8
# dtype: int64

# %%
my_var[2]
# Out:
# np.int64(5)

# %%
my_index = ['A','B','C','E','F','G','H']
my_var2 = pd.Series(my_series,index = my_index)
my_var2
# Out:
# A    2
# B    4
# C    5
# E    3
# F    6
# G    7
# H    8
# dtype: int64

# %%
my_var2['F']
# Out:
# np.int64(6)

# %%
cars = {"Tesla":12,"Mercedes":52,"BMW":72,}
my_cars = pd.Series(cars)
my_cars
# Out:
# Tesla       12
# Mercedes    52
# BMW         72
# dtype: int64

# %% [markdown]
# Pandas DataFrames

# %%
my_data = randn(4,3)

my_row = ['A','B','C','D']
my_cols = ['Monday','Tuesday','Wednesday']
my_df = pd.DataFrame(my_data,my_row,my_cols)
my_df
# Out:
#      Monday   Tuesday  Wednesday
# A  0.409662  1.257251  -0.226777
# B  1.413629  0.981442  -0.800809
# C -0.907417  0.090913  -1.784400
# D -0.289262 -0.774981   0.243229

# %%
my_csv = pd.read_csv('data.csv')
my_csv
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
my_csv.loc[[0,5]]
# Out:
#    Index  Organization Id            Name             Website  \
# 0      1  FAB0d41d5b5d22c     Ferrell LLC  https://price.net/
# 5      6  cC757116fe1C085  Henry-Thompson   http://morse.net/
#
#             Country                                   Description  Founded  \
# 0  Papua New Guinea           Horizontal empowering knowledgebase     1990
# 5           Bahamas  Face-to-face well-modulated customer loyalty     1992
#
#                         Industry  Number of employees
# 0                       Plastics                 3498
# 5  Primary / Secondary Education                 4914

# %%
my_csv.loc[0]
# Out:
# Index                                                    1
# Organization Id                            FAB0d41d5b5d22c
# Name                                           Ferrell LLC
# Website                                 https://price.net/
# Country                                   Papua New Guinea
# Description            Horizontal empowering knowledgebase
# Founded                                               1990
# Industry                                          Plastics
# Number of employees                                   3498
# Name: 0, dtype: object

# %% [raw]
# Pull Data From Pandas DataFrames

# %%
my_csv.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
my_csv.head(9)
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
# 5      6  cC757116fe1C085           Henry-Thompson
# 6      7  219233e8aFF1BC3           Hansen-Everett
# 7      8  ccc93DCF81a31CD            Mcintosh-Mora
# 8      9  0B4F93aA06ED03e                 Carr Inc
#
#                           Website                            Country  \
# 0              https://price.net/                   Papua New Guinea
# 1  http://www.hall-buchanan.info/                            Finland
# 2       http://sullivan-reed.com/                              China
# 3             https://becker.com/                       Turkmenistan
# 4          http://www.brewer.com/                          Mauritius
# ...

# %%
my_csv.tail()
# Out:
#     Index  Organization Id               Name                  Website  \
# 95     96  0a0bfFbBbB8eC7c       Holmes Group    https://mcdowell.org/
# 96     97  BA6Cd9Dae2Efd62           Good Ltd        http://duffy.com/
# 97     98  E7df80C60Abd7f9  Clements-Espinoza  http://www.flowers.net/
# 98     99  AFc285dbE2fEd24         Mendez Inc   https://www.burke.net/
# 99    100  e9eB5A60Cef8354     Watkins-Kaiser  http://www.herring.com/
#
#                         Country                              Description  \
# 95                     Ethiopia   Right-sized zero tolerance focus group
# 96                     Anguilla  Reverse-engineered composite moratorium
# 97  Falkland Islands (Malvinas)                  Progressive modular hub
# 98              Kyrgyz Republic          User-friendly exuding migration
# 99                         Togo            Synergistic background access
#
#     Founded              Industry  Number of employees
# ...

# %%
my_csv.tail(10)
# Out:
#     Index  Organization Id                            Name  \
# 90     91  7ABc3c7ecA03B34                Sampson-Griffith
# 91     92  4e0719FBE38e0aB                 Miles-Dominguez
# 92     93  dEbDAAeDfaed00A                   Rowe and Sons
# 93     94  61BDeCfeFD0cEF5  Valenzuela, Holmes and Rowland
# 94     95  4e91eD25f486110          Best, Wade and Shepard
# 95     96  0a0bfFbBbB8eC7c                    Holmes Group
# 96     97  BA6Cd9Dae2Efd62                        Good Ltd
# 97     98  E7df80C60Abd7f9               Clements-Espinoza
# 98     99  AFc285dbE2fEd24                      Mendez Inc
# 99    100  e9eB5A60Cef8354                  Watkins-Kaiser
#
#                      Website                      Country  \
# 90     http://hendricks.org/                        Benin
# 91    http://www.turner.com/                    Gibraltar
# 92  https://www.simpson.org/                  El Salvador
# 93   https://www.dorsey.net/                       Taiwan
# ...

# %%
my_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                100 non-null    int64
#  1   Organization Id      100 non-null    object
#  2   Name                 100 non-null    object
#  3   Website              100 non-null    object
#  4   Country              100 non-null    object
#  5   Description          100 non-null    object
#  6   Founded              100 non-null    int64
#  7   Industry             100 non-null    object
#  8   Number of employees  100 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 7.2+ KB

# %%
my_csv.dtypes
# Out:
# Index                   int64
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %%
my_csv['Name'].describe()
# Out:
# count             100
# unique            100
# top       Ferrell LLC
# freq                1
# Name: Name, dtype: object

# %%
my_csv['Name']
# Out:
# 0                 Ferrell LLC
# 1     Mckinney, Riley and Day
# 2                  Hester Ltd
# 3              Holder-Sellers
# 4                 Mayer Group
#                ...
# 95               Holmes Group
# 96                   Good Ltd
# 97          Clements-Espinoza
# 98                 Mendez Inc
# 99             Watkins-Kaiser
# Name: Name, Length: 100, dtype: object

# %%
my_csv.Name
# Out:
# 0                 Ferrell LLC
# 1     Mckinney, Riley and Day
# 2                  Hester Ltd
# 3              Holder-Sellers
# 4                 Mayer Group
#                ...
# 95               Holmes Group
# 96                   Good Ltd
# 97          Clements-Espinoza
# 98                 Mendez Inc
# 99             Watkins-Kaiser
# Name: Name, Length: 100, dtype: object

# %%
my_csv.iloc[:,3]
# Out:
# 0                 https://price.net/
# 1     http://www.hall-buchanan.info/
# 2          http://sullivan-reed.com/
# 3                https://becker.com/
# 4             http://www.brewer.com/
#                    ...
# 95             https://mcdowell.org/
# 96                 http://duffy.com/
# 97           http://www.flowers.net/
# 98            https://www.burke.net/
# 99           http://www.herring.com/
# Name: Website, Length: 100, dtype: object

# %% [raw]
# Count Data In A DataFrame

# %%
my_csv['Country'].value_counts(ascending=True)
# Out:
# Country
# Papua New Guinea                1
# Finland                         1
# China                           1
# Turkmenistan                    1
# Mauritius                       1
#                                ..
# United States Virgin Islands    2
# Eritrea                         2
# Togo                            2
# Benin                           3
# Sweden                          3
# Name: count, Length: 84, dtype: int64

# %%
my_csv['Country'].value_counts(normalize=True)
# Out:
# Country
# Sweden                          0.03
# Benin                           0.03
# Korea                           0.02
# Pakistan                        0.02
# United States Virgin Islands    0.02
#                                 ...
# Burundi                         0.01
# Gibraltar                       0.01
# El Salvador                     0.01
# Ethiopia                        0.01
# Anguilla                        0.01
# Name: proportion, Length: 84, dtype: float64

# %%
my_csv['Country'].value_counts()['Benin']
# Out:
# np.int64(3)

# %%
my_csv.groupby('Country').count()
# Out:
#                 Index  Organization Id  Name  Website  Description  Founded  \
# Country
# Anguilla            1                1     1        1            1        1
# Australia           1                1     1        1            1        1
# Bahamas             1                1     1        1            1        1
# Belarus             1                1     1        1            1        1
# Belgium             1                1     1        1            1        1
# ...               ...              ...   ...      ...          ...      ...
# Uruguay             1                1     1        1            1        1
# Uzbekistan          1                1     1        1            1        1
# Vietnam             1                1     1        1            1        1
# Western Sahara      1                1     1        1            1        1
# Zimbabwe            2                2     2        2            2        2
#
#                 Industry  Number of employees
# ...

# %% [raw]
# Add New Columns To Dataframe

# %%
my_csv2 = pd.read_csv('data2.csv')
my_csv2
# Out:
#     Index  Organization Id                     Name  \
# 0     1.0  FAB0d41d5b5d22c              Ferrell LLC
# 1     2.0  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2     3.0  0bFED1ADAE4bcC1               Hester Ltd
# 3     4.0  2bFC1Be8a4ce42f           Holder-Sellers
# 4     NaN              NaN                      NaN
# ..    ...              ...                      ...
# 87    NaN              NaN                      NaN
# 88    NaN              NaN                      NaN
# 89    NaN              NaN                      NaN
# 90    NaN              NaN                      NaN
# 91    NaN              NaN                      NaN
#
#                            Website           Country  \
# 0               https://price.net/  Papua New Guinea
# 1   http://www.hall-buchanan.info/           Finland
# 2        http://sullivan-reed.com/             China
# 3              https://becker.com/      Turkmenistan
# 4                              NaN               NaN
# ...

# %%
newList = np.arange(0,92)
my_csv2['New number'] = newList
my_csv2
# Out:
#     Index  Organization Id                     Name  \
# 0     1.0  FAB0d41d5b5d22c              Ferrell LLC
# 1     2.0  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2     3.0  0bFED1ADAE4bcC1               Hester Ltd
# 3     4.0  2bFC1Be8a4ce42f           Holder-Sellers
# 4     NaN              NaN                      NaN
# ..    ...              ...                      ...
# 87    NaN              NaN                      NaN
# 88    NaN              NaN                      NaN
# 89    NaN              NaN                      NaN
# 90    NaN              NaN                      NaN
# 91    NaN              NaN                      NaN
#
#                            Website           Country  \
# 0               https://price.net/  Papua New Guinea
# 1   http://www.hall-buchanan.info/           Finland
# 2        http://sullivan-reed.com/             China
# 3              https://becker.com/      Turkmenistan
# 4                              NaN               NaN
# ...

# %%
my_csv2['live'] = [True]*len(my_csv2)
my_csv2
# Out:
#     Index  Organization Id                     Name  \
# 0     1.0  FAB0d41d5b5d22c              Ferrell LLC
# 1     2.0  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2     3.0  0bFED1ADAE4bcC1               Hester Ltd
# 3     4.0  2bFC1Be8a4ce42f           Holder-Sellers
# 4     NaN              NaN                      NaN
# ..    ...              ...                      ...
# 87    NaN              NaN                      NaN
# 88    NaN              NaN                      NaN
# 89    NaN              NaN                      NaN
# 90    NaN              NaN                      NaN
# 91    NaN              NaN                      NaN
#
#                            Website           Country  \
# 0               https://price.net/  Papua New Guinea
# 1   http://www.hall-buchanan.info/           Finland
# 2        http://sullivan-reed.com/             China
# 3              https://becker.com/      Turkmenistan
# 4                              NaN               NaN
# ...

# %%
my_csv2.insert(1,'Show support4',[True]*len(my_csv2))
my_csv2
# Out:
#     Index  Show support4  Show support  Organization Id  \
# 0     1.0           True          True  FAB0d41d5b5d22c
# 1     2.0           True          True  6A7EdDEA9FaDC52
# 2     3.0           True          True  0bFED1ADAE4bcC1
# 3     4.0           True          True  2bFC1Be8a4ce42f
# 4     NaN           True          True              NaN
# ..    ...            ...           ...              ...
# 87    NaN           True          True              NaN
# 88    NaN           True          True              NaN
# 89    NaN           True          True              NaN
# 90    NaN           True          True              NaN
# 91    NaN           True          True              NaN
#
#                        Name                         Website           Country  \
# 0               Ferrell LLC              https://price.net/  Papua New Guinea
# 1   Mckinney, Riley and Day  http://www.hall-buchanan.info/           Finland
# ...

# %%
my_csv12 = my_csv2.assign(Horse = [False]*len(my_csv2))
my_csv12
# Out:
#     Index  Show support4  Show support  Organization Id  \
# 0     1.0           True          True  FAB0d41d5b5d22c
# 1     2.0           True          True  6A7EdDEA9FaDC52
# 2     3.0           True          True  0bFED1ADAE4bcC1
# 3     4.0           True          True  2bFC1Be8a4ce42f
# 4     NaN           True          True              NaN
# ..    ...            ...           ...              ...
# 87    NaN           True          True              NaN
# 88    NaN           True          True              NaN
# 89    NaN           True          True              NaN
# 90    NaN           True          True              NaN
# 91    NaN           True          True              NaN
#
#                        Name                         Website           Country  \
# 0               Ferrell LLC              https://price.net/  Papua New Guinea
# 1   Mckinney, Riley and Day  http://www.hall-buchanan.info/           Finland
# ...

# %% [markdown]
# Remove Columns and Rows

# %%
my_csv2.drop('live', axis =1 , inplace =True)
my_csv2
# Out:
#     Index  Show support4  Show support  Organization Id  \
# 0     1.0           True          True  FAB0d41d5b5d22c
# 1     2.0           True          True  6A7EdDEA9FaDC52
# 2     3.0           True          True  0bFED1ADAE4bcC1
# 3     4.0           True          True  2bFC1Be8a4ce42f
# 4     NaN           True          True              NaN
# ..    ...            ...           ...              ...
# 87    NaN           True          True              NaN
# 88    NaN           True          True              NaN
# 89    NaN           True          True              NaN
# 90    NaN           True          True              NaN
# 91    NaN           True          True              NaN
#
#                        Name                         Website           Country  \
# 0               Ferrell LLC              https://price.net/  Papua New Guinea
# 1   Mckinney, Riley and Day  http://www.hall-buchanan.info/           Finland
# ...

# %%
my_csv.drop(3)
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# 5       6  cC757116fe1C085           Henry-Thompson
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 4           http://www.brewer.com/                    Mauritius
# ...

# %% [markdown]
# Grab Rows, Points, and Subsets

# %%
my_csv.iloc[5]
# Out:
# Index                                                             6
# Organization Id                                     cC757116fe1C085
# Name                                                 Henry-Thompson
# Website                                           http://morse.net/
# Country                                                     Bahamas
# Description            Face-to-face well-modulated customer loyalty
# Founded                                                        1992
# Industry                              Primary / Secondary Education
# Number of employees                                            4914
# Name: 5, dtype: object

# %%
my_csv.loc[5]
# Out:
# Index                                                             6
# Organization Id                                     cC757116fe1C085
# Name                                                 Henry-Thompson
# Website                                           http://morse.net/
# Country                                                     Bahamas
# Description            Face-to-face well-modulated customer loyalty
# Founded                                                        1992
# Industry                              Primary / Secondary Education
# Number of employees                                            4914
# Name: 5, dtype: object

# %%
my_csv.loc[5,'Name']
# Out:
# 'Henry-Thompson'

# %%
my_csv.loc[[1,3,6,6],['Name','Country']]
# Out:
#                       Name       Country
# 1  Mckinney, Riley and Day       Finland
# 3           Holder-Sellers  Turkmenistan
# 6           Hansen-Everett      Pakistan
# 6           Hansen-Everett      Pakistan

# %% [markdown]
#  Make Conditional Selections

# %%
my_csv == 'Benin'
# Out:
#     Index  Organization Id   Name  Website  Country  Description  Founded  \
# 0   False            False  False    False    False        False    False
# 1   False            False  False    False    False        False    False
# 2   False            False  False    False    False        False    False
# 3   False            False  False    False    False        False    False
# 4   False            False  False    False    False        False    False
# ..    ...              ...    ...      ...      ...          ...      ...
# 95  False            False  False    False    False        False    False
# 96  False            False  False    False    False        False    False
# 97  False            False  False    False    False        False    False
# 98  False            False  False    False    False        False    False
# 99  False            False  False    False    False        False    False
#
#     Industry  Number of employees
# 0      False                False
# ...

# %%
my_csv[my_csv == 'Benin']
# Out:
#     Index Organization Id Name Website Country Description  Founded Industry  \
# 0     NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 1     NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 2     NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 3     NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 4     NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# ..    ...             ...  ...     ...     ...         ...      ...      ...
# 95    NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 96    NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 97    NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 98    NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
# 99    NaN             NaN  NaN     NaN     NaN         NaN      NaN      NaN
#
#     Number of employees
# ...

# %%
my_csv[my_csv == 'Benin']['Country']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#      ...
# 95    NaN
# 96    NaN
# 97    NaN
# 98    NaN
# 99    NaN
# Name: Country, Length: 100, dtype: object

# %%
my_csv[my_csv == '1992'][['Country','Founded']]
# Out:
#    Country  Founded
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# ..     ...      ...
# 95     NaN      NaN
# 96     NaN      NaN
# 97     NaN      NaN
# 98     NaN      NaN
# 99     NaN      NaN
#
# [100 rows x 2 columns]

# %% [markdown]
# Multiple Conditional Selections

# %%
my_csv[my_csv['Country'] == 'Benin']
# Out:
#     Index  Organization Id              Name                Website Country  \
# 44     45  235fdEFE2cfDa5F   Brock-Blackwell  http://www.small.com/   Benin
# 72     73  dfcA1c84AdB61Ac     Mccall-Holmes   http://www.dean.com/   Benin
# 90     91  7ABc3c7ecA03B34  Sampson-Griffith  http://hendricks.org/   Benin
#
#                           Description  Founded           Industry  \
# 44       Secured foreground emulation     1986  Online Publishing
# 72  Object-based value-added database     2009     Legal Services
# 90   Multi-layered composite paradigm     1972           Textiles
#
#     Number of employees
# 44                 7034
# 72                  696
# 90                 3881

# %%
my_csv[(my_csv['Country'] == 'Benin')  &  (my_csv['Founded'] == 1986)]
# Out:
#     Index  Organization Id             Name                Website Country  \
# 44     45  235fdEFE2cfDa5F  Brock-Blackwell  http://www.small.com/   Benin
#
#                      Description  Founded           Industry  \
# 44  Secured foreground emulation     1986  Online Publishing
#
#     Number of employees
# 44                 7034

# %%
len(my_csv[(my_csv['Country'] == 'Benin')  &  (my_csv['Founded'] == 1986)])
# Out:
# 1

# %%
my_csv[(my_csv['Country'] == 'Benin')  |   (my_csv['Founded'] == 1986)]
# Out:
#     Index  Organization Id                     Name                Website  \
# 20     21  8de40AC4e6EaCa4  Velez, Payne and Coffey     http://burton.com/
# 44     45  235fdEFE2cfDa5F          Brock-Blackwell  http://www.small.com/
# 63     64  055ffEfB2Dd95B0                Riley Ltd      http://wiley.com/
# 72     73  dfcA1c84AdB61Ac            Mccall-Holmes   http://www.dean.com/
# 73     74  208044AC2fe52F3               Massey LLC   https://frazier.biz/
# 90     91  7ABc3c7ecA03B34         Sampson-Griffith  http://hendricks.org/
#
#        Country                                        Description  Founded  \
# 20  Luxembourg                         Mandatory coherent synergy     1986
# 44       Benin                       Secured foreground emulation     1986
# 63      Brazil                    Optional exuding superstructure     1986
# 72       Benin                  Object-based value-added database     2009
# ...

# %%
len(my_csv[(my_csv['Country'] == 'Benin')  |  (my_csv['Founded'] == 1986)])
# Out:
# 6

# %%
my_csv[(my_csv['Country'] == 'Benin')  |  (my_csv['Founded'] == 1986)]['Name']
# Out:
# 20    Velez, Payne and Coffey
# 44            Brock-Blackwell
# 63                  Riley Ltd
# 72              Mccall-Holmes
# 73                 Massey LLC
# 90           Sampson-Griffith
# Name: Name, dtype: object

# %% [markdown]
#  Change And Reset Index

# %%
my_csv['frame name'] = ['Name']*len(my_csv)
my_csv
# Out:
#             Index  Organization Id                     Name  \
# frame name
# Name            1  FAB0d41d5b5d22c              Ferrell LLC
# Name            2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# Name            3  0bFED1ADAE4bcC1               Hester Ltd
# Name            4  2bFC1Be8a4ce42f           Holder-Sellers
# Name            5  9eE8A6a4Eb96C24              Mayer Group
# ...           ...              ...                      ...
# Name           96  0a0bfFbBbB8eC7c             Holmes Group
# Name           97  BA6Cd9Dae2Efd62                 Good Ltd
# Name           98  E7df80C60Abd7f9        Clements-Espinoza
# Name           99  AFc285dbE2fEd24               Mendez Inc
# Name          100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                                    Website                      Country  \
# frame name
# Name                    https://price.net/             Papua New Guinea
# Name        http://www.hall-buchanan.info/                      Finland
# ...

# %%
my_csv.set_index('frame name')
# Out:
#             Index  Organization Id                     Name  \
# frame name
# Name            1  FAB0d41d5b5d22c              Ferrell LLC
# Name            2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# Name            3  0bFED1ADAE4bcC1               Hester Ltd
# Name            4  2bFC1Be8a4ce42f           Holder-Sellers
# Name            5  9eE8A6a4Eb96C24              Mayer Group
# ...           ...              ...                      ...
# Name           96  0a0bfFbBbB8eC7c             Holmes Group
# Name           97  BA6Cd9Dae2Efd62                 Good Ltd
# Name           98  E7df80C60Abd7f9        Clements-Espinoza
# Name           99  AFc285dbE2fEd24               Mendez Inc
# Name          100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                                    Website                      Country  \
# frame name
# Name                    https://price.net/             Papua New Guinea
# Name        http://www.hall-buchanan.info/                      Finland
# ...

# %%
my_csv.reset_index()

# %% [markdown]
# Fix Incomplete Data

# %%
raw_data = { 'A':[1,2,3],'B':[11,np.nan,np.nan],'C':[1,26,31],'D':[17,np.nan,30]}
my_data = pd.DataFrame(raw_data)
my_data
# Out:
#    A     B   C     D
# 0  1  11.0   1  17.0
# 1  2   NaN  26   NaN
# 2  3   NaN  31  30.0

# %%
my_data.dropna()
# Out:
#    A     B   C     D
# 0  1  11.0   1  17.0
# 2  3  32.0  31  30.0

# %%
my_data.dropna(axis = 1)
# Out:
#    A   C
# 0  1   1
# 1  2  26
# 2  3  31

# %%
my_data.dropna(thresh =2, axis =1)
# Out:
#    A   C     D
# 0  1   1  17.0
# 1  2  26   NaN
# 2  3  31  30.0

# %%
my_data.fillna(value = 34)
# Out:
#    A     B   C     D
# 0  1  11.0   1  17.0
# 1  2  34.0  26  34.0
# 2  3  34.0  31  30.0

# %%
my_data.fillna(value = my_data['B'].mean())
# Out:
#    A     B   C     D
# 0  1  11.0   1  17.0
# 1  2  11.0  26  11.0
# 2  3  11.0  31  30.0

# %%
my_data.fillna(value = my_data['A'].sum())
# Out:
#    A     B   C     D
# 0  1  11.0   1  17.0
# 1  2   6.0  26   6.0
# 2  3   6.0  31  30.0

# %% [markdown]
# Dataframe Group By

# %%
my_csv.groupby('Number of employees').describe()
# Out:
#                     Index                                         Founded  \
#                     count  mean std   min   25%   50%   75%   max   count
# Number of employees
# 236                   1.0  98.0 NaN  98.0  98.0  98.0  98.0  98.0     1.0
# 339                   1.0  99.0 NaN  99.0  99.0  99.0  99.0  99.0     1.0
# 346                   1.0  61.0 NaN  61.0  61.0  61.0  61.0  61.0     1.0
# 365                   1.0  31.0 NaN  31.0  31.0  31.0  31.0  31.0     1.0
# 563                   1.0  70.0 NaN  70.0  70.0  70.0  70.0  70.0     1.0
# ...                   ...   ...  ..   ...   ...   ...   ...   ...     ...
# 9097                  1.0  62.0 NaN  62.0  62.0  62.0  62.0  62.0     1.0
# 9315                  1.0  64.0 NaN  64.0  64.0  64.0  64.0  64.0     1.0
# 9443                  1.0  48.0 NaN  48.0  48.0  48.0  48.0  48.0     1.0
# 9698                  1.0  10.0 NaN  10.0  10.0  10.0  10.0  10.0     1.0
# ...

# %% [markdown]
# Count Unique Data In Columns

# %%
my_csv['Country'].value_counts()
# Out:
# Country
# Sweden                          3
# Benin                           3
# Korea                           2
# Pakistan                        2
# United States Virgin Islands    2
#                                ..
# Burundi                         1
# Gibraltar                       1
# El Salvador                     1
# Ethiopia                        1
# Anguilla                        1
# Name: count, Length: 84, dtype: int64

# %%
my_csv['Country'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 my_csv['Country'].unique().head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
pd.DataFrame(my_csv['Country'].unique()).tail(50)
# Out:
#                                0
# 34               Kyrgyz Republic
# 35                       Bolivia
# 36                         Kenya
# 37                     Guatemala
# 38                       Belarus
# 39                        Jersey
# 40                       Grenada
# 41                    Cape Verde
# 42           Trinidad and Tobago
# 43                         Benin
# 44                Western Sahara
# 45      Northern Mariana Islands
# 46                       Germany
# 47                        Canada
# 48                         Tonga
# 49   French Southern Territories
# 50                 Cote d'Ivoire
# 51                       Mayotte
# 52                Cayman Islands
# 53                       Nigeria
# 54              Marshall Islands
# 55                         Palau
# 56                        Turkey
# 57                   Timor-Leste
# 58                       Vietnam
# 59                       Reunion
# 60                        Brazil
# ...

# %% [markdown]
# Apply Functions To DataFrames

# %%
def times100(x):
    return format(x*1000,",d")

# %%
my_csv['Number of employees'].apply(times100)
# Out:
# 0     3,498,000
# 1     4,952,000
# 2     5,287,000
# 3       921,000
# 4     7,870,000
#         ...
# 95    2,988,000
# 96    4,292,000
# 97      236,000
# 98      339,000
# 99    2,785,000
# Name: Number of employees, Length: 100, dtype: object

# %% [markdown]
# pd.DataFrame(my_csv['Number of employees'].apply(times100))

# %% [markdown]
# ### Apply Functions to Multiple Columns

# %%
my_csv
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
def namer(x):
    return "Shadrack"

my_csv[["Name","Founded"]].apply(namer)
# Out:
# Name       Shadrack
# Founded    Shadrack
# dtype: object

# %% [markdown]
# ### Sorting And Ordering Data

# %%
my_csv
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
my_csv.sort_values("Number of employees" , ascending= False)
# Out:
#     Index  Organization Id                        Name  \
# 37     38  19E3a5Bf6dBDc4F                 Cuevas-Moss
# 9      10  738b5aDe6B1C6A5                  Gaines Inc
# 47     48  49aECbDaE6aBD53  Wallace, Madden and Morris
# 63     64  055ffEfB2Dd95B0                   Riley Ltd
# 61     62  EB9f456e8b7022a                  Soto Group
# ..    ...              ...                         ...
# 69     70  902D7Ac8b6d476b                  Newton Inc
# 30     31  ccBcC32adcbc530   Sloan, Mays and Whitehead
# 60     61  bD1bc6bB6d1FeD3                Freeman-Chen
# 98     99  AFc285dbE2fEd24                  Mendez Inc
# 97     98  E7df80C60Abd7f9           Clements-Espinoza
#
#                                Website                      Country  \
# 37       https://dodson-castaneda.net/                    Guatemala
# 9          http://sandoval-hooper.com/                   Uzbekistan
# 47   http://www.blevins-fernandez.biz/                      Germany
# ...

# %% [markdown]
# ### Histograms With Matplotlib

# %%
# %matplotlib inline
my_chart = pd.DataFrame(randn(500,4) , columns = ['Mon','Tue','Wed','Thurs'])


my_chart['Wed'].hist()
# Out:
# <Axes: >

# %%
my_chart['Wed'].hist(bins=50)
# Out:
# <Axes: >

# %%
my_chart['Wed'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_chart['Wed'].hist(bins = 50,grid = False, legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Area Plots With Matplotlib

# %%
my_chart.abs().plot(kind='area' , alpha = 0.3 , title = ' area is oke' )
# Out:
# <Axes: title={'center': ' area is oke'}>

# %%
my_chart[['Mon','Tue']].abs().plot(kind='area' , alpha = 0.3 , title = ' area is oke', table= True )
# Out:
# <Axes: title={'center': ' area is oke'}>

# %% [markdown]
# ### Bar Charts With Matplotlib

# %%
my_chart.abs().plot(kind ='bar' , stacked =True , alpha = 0.4 ,title = 'true' )
# Out:
# <Axes: title={'center': 'true'}>

# %%
my_chart.plot().bar()
# Out:
# <BarContainer object of 1 artists>

# %%
my_chart.abs().plot(kind = 'line',lw=1)
# Out:
# <Axes: >

# %%
my_chart[['Mon','Tue']].abs().plot(kind = 'line',lw=1)
# Out:
# <Axes: >

# %%
my_chart[['Mon','Tue']].abs().plot(kind = 'line',lw=1,figsize = (10,5),legend=False)
# Out:
# <Axes: >

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 my_chart.plot().line('name','fun')
#
# AttributeError: 'Axes' object has no attribute 'line'

# %% [markdown]
# ### Scatterplots With Matplotlib

# %%
my_chart.plot(kind='scatter',x='Mon',y='Tue' ,c='Wed' ,cmap = 'magma',alpha = 0.4, title = ' my nname')
# Out:
# <Axes: title={'center': ' my nname'}, xlabel='Mon', ylabel='Tue'>

# %% [markdown]
# ### Box Plots With Matplotlib

# %%
my_chart.plot(kind = 'box', figsize =  (10,3), cmap = 'jet' , title = ' my name ')
# Out:
# <Axes: title={'center': ' my name '}>

# %% [markdown]
# ### Hex Bin Plots

# %%
my_chart.plot(kind ='hexbin',x ='Mon',y='Tue' , gridsize = 10 , cmap ='jet' , title = ' hello ',grid = True)
# Out:
# <Axes: title={'center': ' hello '}, xlabel='Mon', ylabel='Tue'>

# %% [markdown]
# ### Density and KDE Plots

# %%
my_chart.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
my_chart.plot(kind = 'density' , lw =3 ,grid = True, title = ' may na ')
# Out:
# <Axes: title={'center': ' may na '}, ylabel='Density'>
